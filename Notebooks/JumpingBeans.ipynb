yi3 = [0.0148, 0.04075265392024377, 0.06670530784048753, 0.09265796176073131, 0.11861061568097507, 0.14456326960121882, 0.17051592352146258, 0.19646857744170634, 0.2224212313619501, 0.24837388528219387, 0.27432653920243766, 0.3002791931226814, 0.3262318470429252, 0.35218450096316894, 0.3781371548834127, 0.40408980880365647]

ti4 = [0, 0.14747720016517848, 0.24181024042488733, 0.30853664317244966, 0.36320452638410944, 0.41065824695443165, 0.4531697955484993, 0.49202188102080413, 0.5280229154203746, 0.5617213428514299, 0.5935095069336257, 0.6236795672670199, 0.652456029500961, 0.6800158367552483, 0.706501384318334]
yi4 = [0.016200000000000003, 0.04355265392024377, 0.07090530784048754, 0.09825796176073132, 0.1256106156809751, 0.15296326960121884, 0.18031592352146258, 0.20766857744170633, 0.23502123136195008, 0.26237388528219385, 0.2897265392024376, 0.3170791931226814, 0.3444318470429252, 0.37178450096316895, 0.3991371548834127]

# %%
fig=plt.figure(figsize=(10,7))
#plt.title('Parabolas for different drop heights ', fontsize = 22)
plt.xlabel('t', linespacing=1, fontsize = 18)
plt.ylabel('y', linespacing=1, fontsize = 18)

plt.plot(ti1, yi1, linestyle='--',color='blue', linewidth=2, label = 'E1')
plt.plot(ti2, yi2, linestyle='--',color='red', linewidth=2, label = 'E2')
plt.plot(ti3, yi3, linestyle='--',color='green', linewidth=2, label = 'E2')
plt.plot(ti4, yi4, linestyle='--',color='black', linewidth=2, label = 'E2')

plt.xticks(size = 'xx-large')
plt.yticks(size = 'xx-large')
#plt.legend(loc='upper left', fontsize = 14, shadow=True)
plt.grid(True)
#plt.axis([-0.05, 1, 0, 1.7])
plt.gca().invert_yaxis() 

# Mostramos en pantalla
plt.show()

# %%
angles = [5,10,15,20]
tfinal = [1.4461169603165225, 1.0245102523794645,0.8391764903037162,0.7300045742983255]

# %%
fig=plt.figure(figsize=(10,7))
#plt.title('Parabolas for different drop heights ', fontsize = 22)
plt.xlabel('t', linespacing=1, fontsize = 18)
plt.ylabel('y', linespacing=1, fontsize = 18)

plt.plot(angles, tfinal, linestyle='--',color='blue', linewidth=2, label = 'E1')

plt.xticks(size = 'xx-large')
plt.yticks(size = 'xx-large')
#plt.legend(loc='upper left', fontsize = 14, shadow=True)
plt.grid(True)
#plt.axis([-0.05, 1, 0, 1.7])
#plt.gca().invert_yaxis() 

# Mostramos en pantalla
plt.show()
